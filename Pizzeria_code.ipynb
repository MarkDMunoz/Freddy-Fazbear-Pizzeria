# %%
# setting up our workstation and loading the data into pandas data frame
import pandas as pd
import matplotlib as mpt
import numpy as np
import datetime as dt

# %%
pd.read_csv("Pizza_Results.csv")
df = pd.read_csv("Pizza_Results.csv")

# %%
df
# Out:
#       pizza_type_id                        name category
# 0          hawaiian          The Hawaiian Pizza  Classic  \
# 1       classic_dlx    The Classic Deluxe Pizza  Classic
# 2       five_cheese       The Five Cheese Pizza   Veggie
# 3         ital_supr   The Italian Supreme Pizza  Supreme
# 4          mexicana          The Mexicana Pizza   Veggie
# ...             ...                         ...      ...
# 48615   ckn_alfredo   The Chicken Alfredo Pizza  Chicken
# 48616   four_cheese       The Four Cheese Pizza   Veggie
# 48617    napolitana        The Napolitana Pizza  Classic
# 48618      mexicana          The Mexicana Pizza   Veggie
# 48619       bbq_ckn  The Barbecue Chicken Pizza  Chicken
#
#                                              ingredients       pizza_id
# 0               Sliced Ham, Pineapple, Mozzarella Cheese     hawaiian_m  \
# 1      Pepperoni, Mushrooms, Red Onions, Red Peppers,...  classic_dlx_m
# ...

# %%
# Dropping the columns that were duplicated
df.drop(['pizza_type_id.1', 'pizza_id.1','order_id.1'], axis = 1, inplace=True)

# %%
df
# Out:
#       pizza_type_id                        name category
# 0          hawaiian          The Hawaiian Pizza  Classic  \
# 1       classic_dlx    The Classic Deluxe Pizza  Classic
# 2       five_cheese       The Five Cheese Pizza   Veggie
# 3         ital_supr   The Italian Supreme Pizza  Supreme
# 4          mexicana          The Mexicana Pizza   Veggie
# ...             ...                         ...      ...
# 48615   ckn_alfredo   The Chicken Alfredo Pizza  Chicken
# 48616   four_cheese       The Four Cheese Pizza   Veggie
# 48617    napolitana        The Napolitana Pizza  Classic
# 48618      mexicana          The Mexicana Pizza   Veggie
# 48619       bbq_ckn  The Barbecue Chicken Pizza  Chicken
#
#                                              ingredients       pizza_id size
# 0               Sliced Ham, Pineapple, Mozzarella Cheese     hawaiian_m    M  \
# 1      Pepperoni, Mushrooms, Red Onions, Red Peppers,...  classic_dlx_m    M
# ...

# %%
# checking for null values, there is no values to replace in categorical or numerical columns
df.isna().sum()
# Out:
# pizza_type_id       0
# name                0
# category            0
# ingredients         0
# pizza_id            0
# size                0
# price               0
# order_details_id    0
# order_id            0
# quantity            0
# date                0
# time                0
# dtype: int64

# %%
# printing data type columns
df.dtypes
# Out:
# pizza_type_id        object
# name                 object
# category             object
# ingredients          object
# pizza_id             object
# size                 object
# price               float64
# order_details_id      int64
# order_id              int64
# quantity              int64
# date                 object
# time                 object
# dtype: object

# %%
# Date and time are not being displayed as date and are seen as objects
df['date'] = pd.to_datetime(df['date'])
df['time'] = pd.to_datetime(df['time'])
# Out:
# C:\Users\sucki\AppData\Local\Temp\ipykernel_18036\2934609196.py:3: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df['time'] = pd.to_datetime(df['time'])

# %%
print(df['date'])
print(df['time'])
# Out:
# 0       2015-01-01
# 1       2015-01-01
# 2       2015-01-01
# 3       2015-01-01
# 4       2015-01-01
#            ...
# 48615   2015-12-31
# 48616   2015-12-31
# 48617   2015-12-31
# 48618   2015-12-31
# 48619   2015-12-31
# Name: date, Length: 48620, dtype: datetime64[ns]
# 0       2023-06-15 11:38:36
# 1       2023-06-15 11:57:40
# 2       2023-06-15 11:57:40
# 3       2023-06-15 11:57:40
# 4       2023-06-15 11:57:40
#                 ...
# 48615   2023-06-15 21:23:10
# 48616   2023-06-15 21:23:10
# 48617   2023-06-15 21:23:10
# 48618   2023-06-15 22:09:54
# 48619   2023-06-15 23:02:05
# Name: time, Length: 48620, dtype: datetime64[ns]

# %%
# i want to see how much pizza was ordered during the amount of time in business 
pizzas_per_day = df.groupby(df['date'].dt.date)['quantity'].sum()

# %%
pizzas_per_day
# Out:
# date
# 2015-01-01    162
# 2015-01-02    165
# 2015-01-03    158
# 2015-01-04    106
# 2015-01-05    125
#              ...
# 2015-12-27     89
# 2015-12-28    102
# 2015-12-29     80
# 2015-12-30     82
# 2015-12-31    178
# Name: quantity, Length: 358, dtype: int64

# %%
pizzas_per_day.plot()
# Out:
# <Axes: xlabel='date'>

# %%
pizza_counts = df.groupby('pizza_id')['quantity'].sum()

# Sort the pizza counts in descending order
sorted_pizza_counts = pizza_counts.sort_values(ascending=False)

# %%
print(sorted_pizza_counts.head(10))
# Out:
# pizza_id
# big_meat_s       1914
# thai_ckn_l       1410
# five_cheese_l    1409
# four_cheese_l    1316
# classic_dlx_m    1181
# spicy_ital_l     1109
# hawaiian_s       1020
# southw_ckn_l     1016
# bbq_ckn_l         992
# bbq_ckn_m         956
# Name: quantity, dtype: int64

# %%
# Calculating Revenue 
revenue = df['price'] * df['quantity']

print(f'the business is generating {revenue.sum()} this year')
# Out:
# the business is generating 817860.0508384705 this year

# %%
df[['time', 'quantity', 'price']].value_counts()
# Out:
# time                 quantity  price
# 2023-06-15 13:27:51  1         16.000000    7
# 2023-06-15 13:34:07  1         20.750000    6
# 2023-06-15 13:35:54  1         16.500000    6
# 2023-06-15 12:42:35  1         20.750000    6
# 2023-06-15 11:59:10  1         16.750000    6
#                                            ..
# 2023-06-15 14:44:47  1         12.500000    1
# 2023-06-15 14:44:49  1         17.950001    1
# 2023-06-15 14:44:50  1         12.500000    1
#                                17.950001    1
# 2023-06-15 23:05:52  1         16.500000    1
# Name: count, Length: 43054, dtype: int64

# %%
#df.to_csv("Freddy_Data.csv", index=False)
